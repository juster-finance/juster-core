# %% [markdown]
# ### Model:

# %%
import sys
sys.path.insert(0, '../../tests')

# %%
from event_model import EventModel
from sgqlc.endpoint.http import HTTPEndpoint
import pandas as pd
endpoint = HTTPEndpoint('https://api.granadanet.juster.fi/v1/graphql')

# %%
event_data = endpoint("""
query MyQuery {
  eventByPk(id: 0) {
    betsCloseTime
    closedDynamics
    closedOracleTime
    closedRate
    createdTime
    liquidityPercent
  }
}
""")
event_data = event_data['data']['eventByPk']

# %%
to_timestamp = ['betsCloseTime', 'closedOracleTime', 'createdTime']
event_data.update(**{field: pd.Timestamp(event_data[field]) for field in to_timestamp})

# %%
deposits_raw = endpoint("""
query MyQuery {
  eventByPk(id: 0) {
    deposits(where: {}) {
      amountAboveEq
      amountBelow
      createdTime
      user {
        address
      }
      shares
      id
    }
  }
}
""")
deposits = pd.json_normalize(deposits_raw['data']['eventByPk']['deposits'])
deposits['amount'] = deposits[['amountAboveEq', 'amountBelow']].max(axis=1)

# %%
bets_raw = endpoint("""
query MyQuery {
  eventByPk(id: 0) {
    bets {
      amount
      createdTime
      reward
      side
      user {
        address
      }
      id
    }
  }
}
""")
bets = pd.json_normalize(bets_raw['data']['eventByPk']['bets'])

# %%
actions = pd.concat({
    'deposit': deposits,
    'bet': bets
}, names=['action', '_']).sort_values(['createdTime']).reset_index().drop('_', axis=1)
actions['createdTime'] = actions.createdTime.map(pd.Timestamp)

betting_time = (event_data['betsCloseTime'] - event_data['createdTime']).seconds
actions['delta_from_start'] = actions.createdTime - event_data['createdTime']
actions['time_passed'] = actions.delta_from_start.map(lambda x: x.seconds / betting_time)

actions = actions.reset_index()

# %% [markdown]
# # Data from granada (hide me and maybe remove):

# %%
from urllib.parse import urlencode
import time
import requests
import pandas as pd

def get_operations(address, last_id=None):
    method = f'https://api.granadanet.tzkt.io/v1/accounts/{address}/operations'
    params = {
        'type': 'transaction',
        'limit': '1000',
        'status': 'applied',
        'sort': '1'
    }

    if last_id:
        params['lastId'] = last_id

    data = requests.get(f'{method}?{urlencode(params)}').json()
    return data

def get_operations_deep(address, last_id=None, depth=None):
    depth = depth or 10
    data = []

    for _ in range(depth):
        new_data = get_operations(address, last_id)
        print(f'-- last_id: {last_id}, received {len(new_data)} items')
        if len(new_data) == 0:
            break

        last_id = new_data[-1]['id']
        data += new_data
        time.sleep(0.5)

    return data

def make_df(data):
    df = pd.json_normalize(data)

    df['internal'] = df['sender.address'] == 'KT1T1w1E2iMyQpogneqR2552pvrEpF7AZ8kL'
    df[ df['internal'] ]['parameter.entrypoint'].value_counts()
    df['address_counter'] = df['sender.address'] + '//' + df['counter'].astype(str)
    # unique operations:
    df['hash_counter'] = df['hash'] + '//' + df['counter'].astype(str)
    return df


def prepare_primary_calls(df):
    calls = df[ ~df['internal'] ]
    assert not any(calls['parameter.entrypoint'].isna())
    return calls

def prepare_internal_calls(df):
    internal = df[ df['internal'] ]
    return internal

def fill_internal_with_primary(internal, calls):

    # removing callbacks to make hash_counter unique key for transaction identifier:
    calls_without_callbacks = calls[
        ~calls['parameter.entrypoint'].isin(['closeCallback', 'startMeasurementCallback'])
    ]
    assert not calls_without_callbacks.hash_counter.duplicated().any()

    # adding data about source transaction to the internals:
    parent_mapping = calls_without_callbacks.set_index('hash_counter')[[
        'parameter.entrypoint', 'amount', 'parameter.value.eventId', 'parameter.value.participantAddress'
    ]]
    parent_mapping = parent_mapping.rename(columns=lambda name: f'parent.{name}')

    internal = internal.join(parent_mapping, on='hash_counter')
    assert not any(internal['parent.parameter.entrypoint'].isna())

    return internal

def check_internal_amount_stats(internal):
    # checking that close/startMeasurement is converge
    internal_amount_stats = internal.groupby('parent.parameter.entrypoint').amount.sum()

    total_bets = calls[ calls['parameter.entrypoint'] == 'bet' ]['amount'].sum()
    total_pl = calls[ calls['parameter.entrypoint'] == 'provideLiquidity' ]['amount'].sum()
    total_event_lock = calls[ calls['parameter.entrypoint'] == 'newEvent' ]['amount'].sum()

    # total_bets + total_pl + total_event_lock - internal.amount.sum()

    should_be_zero = (total_event_lock
        - internal_amount_stats['close']
        - internal_amount_stats['startMeasurement']
        - internal_amount_stats['triggerForceMajeure']
    )

    assert should_be_zero == 0

# %%
ADDRESS = 'KT1T1w1E2iMyQpogneqR2552pvrEpF7AZ8kL'
data = get_operations_deep(ADDRESS, depth=3)
df = make_df(data)

calls = prepare_primary_calls(df)
internal = prepare_internal_calls(df)
internal = fill_internal_with_primary(internal, calls)
check_internal_amount_stats(internal)
# Out:
# -- last_id: None, received 1000 items
# -- last_id: 3972924, received 261 items
# -- last_id: 3957114, received 0 items

# %%
# Then there are problem with withdrawals:
withdrawals = internal[ internal['parent.parameter.entrypoint'] == 'withdraw' ]
assert not withdrawals['parent.parameter.value.eventId'].isna().any()

bets = calls[calls['parameter.entrypoint'] == 'bet']
pls = calls[calls['parameter.entrypoint'] == 'provideLiquidity']

claims = internal[ internal['parent.parameter.entrypoint'] == 'claimRetainedProfits' ]
bets.amount.sum() + pls.amount.sum() - withdrawals.amount.sum() - claims.amount.sum()
# Out:
# 2934694

# %%
bets_by_events = bets.groupby('parameter.value.eventId').amount.sum()
pls_by_events = pls.groupby('parameter.value.eventId').amount.sum()
wit_by_events = withdrawals.groupby('parent.parameter.value.eventId').amount.sum()

# %%
event_stats = pd.DataFrame({
    'pls': pls_by_events,
    'bets': bets_by_events,
    'withdrawals': wit_by_events
}).fillna(0)

event_stats['net_value'] = event_stats.pls + event_stats.bets - event_stats.withdrawals
event_stats[ event_stats['net_value'] != 0 ]
# Out:
#         pls        bets  withdrawals  net_value
# 0  97000000  34650000.0    129606696  2043304.0
# 1  50000000  22850000.0     71914716   935284.0
# 2  77000000  16650000.0     93618630    31370.0

# %%
event_stats.net_value.sum() - claims.amount.sum()
# Out:
# 2934694.0

# %%
def detect_bet(bet):
    if 'Left' in bet.parameters:
        return 'aboveEq'
    elif 'Right' in bet.parameters:
        return 'below'
    else:
        raise Exception('wrong bet')

bets = bets.assign(betPool = bets.apply(detect_bet, axis=1))

# %%
from pytezos import pytezos
from tqdm import tqdm

address = 'KT1T1w1E2iMyQpogneqR2552pvrEpF7AZ8kL'
client = pytezos.using(
    key='../../../juster-maker/keys/tz1fvzdyC7s4mMhBrmG38kasaZjE9PHPgFEu.json',
    shell='https://rpc.tzkt.io/granadanet'
)
contract = client.contract(address)
client_address = client.key.public_key_hash()

# %%
event_id = '0'
event_bets = bets[ bets['parameter.value.eventId'] == event_id ]
total_bets = event_bets.groupby(['sender.address', 'betPool']).amount.sum().unstack()

event_pls = pls[ pls['parameter.value.eventId'] == event_id ]
event_withdrawals = withdrawals[ withdrawals['parent.parameter.value.eventId'] == event_id ]

event_stats = total_bets.copy()
event_stats['pls'] = event_pls.groupby('sender.address').amount.sum()
event_stats['withdrawals'] = event_withdrawals.groupby('parent.parameter.value.participantAddress').amount.sum()

# need storage state before first withdrawal:
last_storage_level = event_withdrawals.level.min() - 1
last_storage = contract.using(block_id=last_storage_level).storage

event_at_the_end = last_storage['events'][0]()

# %%
calls[['sender.address', 'parameter.entrypoint', 'timestamp', 'level']]
# Out:
#                             sender.address  parameter.entrypoint  \
# 1     tz1fvzdyC7s4mMhBrmG38kasaZjE9PHPgFEu  claimRetainedProfits
# 3     tz1fvzdyC7s4mMhBrmG38kasaZjE9PHPgFEu              withdraw
# 6     tz1fvzdyC7s4mMhBrmG38kasaZjE9PHPgFEu              withdraw
# 9     tz1fvzdyC7s4mMhBrmG38kasaZjE9PHPgFEu              withdraw
# 12    tz1fvzdyC7s4mMhBrmG38kasaZjE9PHPgFEu              withdraw
# ...                                    ...                   ...
# 1256  tz1VRV2jtEVgupzgf4YoXQxK9x6Vksh9tPdM      provideLiquidity
# 1257  tz1RorGpGL42VEkd3zRBK5s8uAk3uuismC2y      provideLiquidity
# 1258  tz1UZbnprFkQe4qR11m8MFvs19JuEN3r8rG6              newEvent
# 1259  tz1fvzdyC7s4mMhBrmG38kasaZjE9PHPgFEu              newEvent
# 1260  tz1VRV2jtEVgupzgf4YoXQxK9x6Vksh9tPdM              newEvent
#
#                  timestamp   level
# 1     2021-10-05T14:36:33Z  538741
# 3     2021-10-05T14:34:53Z  538738
# 6     2021-10-05T14:31:23Z  538730
# 9     2021-10-05T14:31:23Z  538730
# 12    2021-10-05T14:31:23Z  538730
# ...                    ...     ...
# 1256  2021-08-23T16:38:35Z  370979
# 1257  2021-08-23T16:38:35Z  370979
# 1258  2021-08-23T16:37:00Z  370975
# 1259  2021-08-23T16:37:00Z  370975
# 1260  2021-08-23T16:37:00Z  370975
#
# [858 rows x 4 columns]

# %%
calls.iloc[0]
# Out:
# type                                                                          transaction
# id                                                                                6750900
# level                                                                              538741
# timestamp                                                            2021-10-05T14:36:33Z
# block                                   BL1NHgjvTiRJy6D6mmEhNtU7QinF8xd2T2rDyMtdSUMeeT...
# hash                                    onkBYuw49AnThFvvChgjENbxXyMNBZWTdxBS6q8mJrZXr2...
# counter                                                                            413424
# nonce                                                                                 NaN
# gasLimit                                                                            15000
# gasUsed                                                                             10957
# storageLimit                                                                          100
# storageUsed                                                                             0
# bakerFee                                                                             1796
# storageFee                                                                              0
# allocationFee                                                                           0
# amount                                                                                  0
# status                                                                            applied
# hasInternals                                                                         True
# initiator.address                                                                     NaN
# sender.address                                       tz1fvzdyC7s4mMhBrmG38kasaZjE9PHPgFEu
# target.address                                       KT1T1w1E2iMyQpogneqR2552pvrEpF7AZ8kL
# parameters                              {"entrypoint":"claimRetainedProfits","value":{...
# parameter.entrypoint                                                 claimRetainedProfits
# parameter.value.eventId                                                               NaN
# parameter.value.participantAddress                                                    NaN
# parameter.value                                                                       NaN
# parameter.value.rate                                                                  NaN
# parameter.value.lastUpdate                                                            NaN
# parameter.value.currencyPair                                                          NaN
# parameter.value.string                                                                NaN
# parameter.value.contract                                                              NaN
# parameter.value.betsCloseTime                                                         NaN
# parameter.value.measurePeriod                                                         NaN
# parameter.value.targetDynamics                                                        NaN
# parameter.value.liquidityPercent                                                      NaN
# parameter.value.maxSlippage                                                           NaN
# parameter.value.expectedRatioBelow                                                    NaN
# parameter.value.expectedRatioAboveEq                                                  NaN
# parameter.value.minimalWinAmount                                                      NaN
# internal                                                                            False
# address_counter                              tz1fvzdyC7s4mMhBrmG38kasaZjE9PHPgFEu//413424
# hash_counter                            onkBYuw49AnThFvvChgjENbxXyMNBZWTdxBS6q8mJrZXr2...
# Name: 1, dtype: object

# %%
actions
# Out:
#      action  amountAboveEq  amountBelow               createdTime      shares  \
# 0   deposit       1.000000     1.000000 2021-08-23 16:38:35+00:00  100.000000
# 1       bet            NaN          NaN 2021-08-23 16:40:05+00:00         NaN
# 2       bet            NaN          NaN 2021-08-23 16:40:20+00:00         NaN
# 3       bet            NaN          NaN 2021-08-23 16:41:25+00:00         NaN
# 4   deposit       2.000000     0.720001 2021-08-23 16:41:25+00:00  119.999760
# ..      ...            ...          ...                       ...         ...
# 90      bet            NaN          NaN 2021-08-23 17:24:05+00:00         NaN
# 91  deposit       1.950027     2.000000 2021-08-23 17:24:20+00:00  197.481169
# 92      bet            NaN          NaN 2021-08-23 17:24:50+00:00         NaN
# 93      bet            NaN          NaN 2021-08-23 17:25:20+00:00         NaN
# 94      bet            NaN          NaN 2021-08-23 17:25:35+00:00         NaN
#
#      id                          user.address  amount    reward      side  \
# 0     3  tz1iosWvYEaNdFXC7w6wcn5rFFfFuWaKUMVK    1.00       NaN       NaN
# 1     1  tz1UZbnprFkQe4qR11m8MFvs19JuEN3r8rG6    1.00  1.499998  ABOVE_EQ
# 2     3  tz1iosWvYEaNdFXC7w6wcn5rFFfFuWaKUMVK    0.10  0.433330     BELOW
# 3     5  tz1VRV2jtEVgupzgf4YoXQxK9x6Vksh9tPdM    0.25  0.833860     BELOW
# 4     6  tz1UZbnprFkQe4qR11m8MFvs19JuEN3r8rG6    2.00       NaN       NaN
# ..  ...                                   ...     ...       ...       ...
# 90  150  tz1UZbnprFkQe4qR11m8MFvs19JuEN3r8rG6    0.10  0.197601     BELOW
# 91   51  tz1VRV2jtEVgupzgf4YoXQxK9x6Vksh9tPdM    2.00       NaN       NaN
# 92  153  tz1fvzdyC7s4mMhBrmG38kasaZjE9PHPgFEu    1.00  2.014518  ABOVE_EQ
# 93  154  tz1iosWvYEaNdFXC7w6wcn5rFFfFuWaKUMVK    0.10  0.199523     BELOW
# 94  155  tz1RorGpGL42VEkd3zRBK5s8uAk3uuismC2y    0.10  0.199310     BELOW
#
#    delta_from_start  time_passed
# 0   0 days 00:01:35     0.001101
# 1   0 days 00:03:05     0.002144
# 2   0 days 00:03:20     0.002318
# 3   0 days 00:04:25     0.003071
# 4   0 days 00:04:25     0.003071
# ..              ...          ...
# 90  0 days 00:47:05     0.032742
# 91  0 days 00:47:20     0.032916
# 92  0 days 00:47:50     0.033264
# 93  0 days 00:48:20     0.033611
# 94  0 days 00:48:35     0.033785
#
# [95 rows x 12 columns]

# %% [markdown]
# # Model:

# %%
# resorting:
actions.loc[ actions.index == 19, 'index' ] = 17.5
actions.loc[ actions.index == 22, 'index' ] = 20.5
actions.loc[ actions.index == 32, 'index' ] = 29.5
# actions.loc[ actions.index == 34, 'index' ] = 32.5
actions = actions.sort_values('index')

# %%
event = EventModel(winning_pool='below', fee=event_data['liquidityPercent'])

for _, action in actions.iterrows():
    amount = action.amount*10**6
    pool_a = event.to_dict()['pool_a'] / 10**6
    pool_b = event.to_dict()['pool_b'] / 10**6
    general_info = f'{pool_a:5.2f}:{pool_b:5.2f} | {action.time_passed:10.8f} | ({action.name})'

    if action.action == 'bet':
        side = 'aboveEq' if action.side == 'ABOVE_EQ' else 'below'
        reward = (amount + event.calc_bet_profit(amount, side, action.time_passed)) / 10**6
        event.bet(
            action['user.address'],
            amount,
            side,
            action.time_passed)

        divergence = action.reward / reward - 1
        action_side = f'{action.action}:{side}'
        print(f'{action_side:14s}: {action.amount:5.2f}, '
              + f'reward contract: {action.reward:6.2f}, reward model: {reward:6.2f}, '
              + f'divergence: {divergence*100:5.2f}%, {general_info}')

    elif action.action == 'deposit':
        a = int(action.amountAboveEq)
        b = int(action.amountBelow)
        a, b, shares = event.calc_provided_shares(amount, a, b)
        shares /= 10**6
        event.provide_liquidity(
            action['user.address'],
            amount,
            a,
            b)

        divergence = action.shares / shares - 1
        print(f'{action.action:14s}: {action.amount:5.2f}, '
              + f'shares contract: {action.shares:6.2f}, shares model: {shares:6.2f}, '
              + f'divergence: {divergence*100:5.2f}%, {general_info}')

    # print(f'{action.action:10s}: {action.amount:.3f}, A: {a:2.2f}, B: {b:2.2f}')
# Out:
# deposit       :  1.00, shares contract: 100.00, shares model: 100.00, divergence:  0.00%,  0.00: 0.00 | 0.00110107 | (0)
# bet:aboveEq   :  1.00, reward contract:   1.50, reward model:   1.50, divergence:  0.00%,  1.00: 1.00 | 0.00214418 | (1)
# bet:below     :  0.10, reward contract:   0.43, reward model:   0.43, divergence:  0.01%,  2.00: 0.50 | 0.00231803 | (2)
# deposit       :  2.00, shares contract: 120.00, shares model: 120.00, divergence:  0.00%,  1.67: 0.60 | 0.00307140 | (3)
# bet:below     :  0.25, reward contract:   0.83, reward model:   0.83, divergence:  0.01%,  3.67: 1.32 | 0.00307140 | (4)
# bet:below     :  0.25, reward contract:   0.67, reward model:   0.67, divergence:  0.01%,  3.08: 1.57 | 0.00376681 | (5)
# bet:aboveEq   :  0.50, reward contract:   0.79, reward model:   0.79, divergence:  0.00%,  2.66: 1.82 | 0.00446222 | (6)
# deposit       :  5.00, shares contract: 348.17, shares model: 348.16, divergence:  0.00%,  3.16: 1.53 | 0.00463607 | (7)
# bet:aboveEq   :  0.10, reward contract:   0.15, reward model:   0.15, divergence:  0.00%,  8.16: 3.96 | 0.00515763 | (8)
# bet:below     :  0.50, reward contract:   1.44, reward model:   1.44, divergence:  0.01%,  8.26: 3.91 | 0.00533148 | (9)
# bet:aboveEq   :  0.10, reward contract:   0.16, reward model:   0.16, divergence:  0.01%,  7.32: 4.41 | 0.00602689 | (10)
# bet:aboveEq   :  1.00, reward contract:   1.52, reward model:   1.52, divergence:  0.01%,  7.42: 4.35 | 0.00672230 | (11)
# bet:below     :  1.00, reward contract:   2.74, reward model:   2.74, divergence:  0.01%,  8.42: 3.83 | 0.00689615 | (12)
# bet:below     :  1.00, reward contract:   2.15, reward model:   2.15, divergence:  0.01%,  6.68: 4.83 | 0.00741771 | (13)
# bet:below     :  0.10, reward contract:   0.19, reward model:   0.19, divergence:  0.00%,  5.54: 5.83 | 0.00776541 | (14)
# deposit       :  2.00, shares contract: 191.54, shares model: 191.52, divergence:  0.01%,  5.44: 5.93 | 0.00828697 | (15)
# bet:aboveEq   :  0.25, reward contract:   0.51, reward model:   0.51, divergence:  0.02%,  7.28: 7.93 | 0.00898238 | (16)
# bet:aboveEq   :  1.00, reward contract:   1.90, reward model:   1.90, divergence:  0.01%,  7.53: 7.67 | 0.00915624 | (17)
# bet:below     :  1.00, reward contract:   2.10, reward model:   2.10, divergence:  0.01%,  8.53: 6.77 | 0.00990960 | (19)
# bet:aboveEq   :  0.50, reward contract:   0.99, reward model:   0.99, divergence:  0.01%,  7.43: 7.77 | 0.00990960 | (18)
# deposit       :  5.00, shares contract: 479.10, shares model: 479.02, divergence:  0.02%,  7.93: 7.28 | 0.01072091 | (20)
# deposit       :  1.00, shares contract:  95.82, shares model:  95.80, divergence:  0.02%, 12.93:11.87 | 0.01130042 | (22)
# bet:aboveEq   :  0.10, reward contract:   0.19, reward model:   0.19, divergence:  0.01%, 13.93:12.79 | 0.01130042 | (21)
# deposit       :  1.00, shares contract:  95.14, shares model:  95.12, divergence:  0.02%, 14.03:12.70 | 0.01199583 | (23)
# bet:aboveEq   :  0.25, reward contract:   0.47, reward model:   0.47, divergence:  0.02%, 15.03:13.60 | 0.01216968 | (24)
# bet:below     :  1.00, reward contract:   2.06, reward model:   2.06, divergence:  0.01%, 15.28:13.38 | 0.01269124 | (25)
# deposit       : 10.00, shares contract: 994.26, shares model: 994.12, divergence:  0.01%, 14.22:14.38 | 0.01286509 | (26)
# bet:below     :  1.00, reward contract:   1.95, reward model:   1.95, divergence:  0.01%, 24.10:24.38 | 0.01303894 | (27)
# deposit       :  1.00, shares contract:  95.51, shares model:  95.49, divergence:  0.01%, 23.15:25.38 | 0.01356050 | (28)
# bet:aboveEq   :  1.00, reward contract:   2.05, reward model:   2.05, divergence:  0.02%, 24.07:26.38 | 0.01356050 | (29)
# deposit       :  5.00, shares contract: 497.38, shares model: 497.31, divergence:  0.02%, 25.07:25.33 | 0.01373435 | (32)
# bet:below     :  0.25, reward contract:   0.50, reward model:   0.50, divergence:  0.01%, 30.01:30.33 | 0.01373435 | (30)
# bet:below     :  0.25, reward contract:   0.49, reward model:   0.49, divergence:  0.01%, 29.77:30.58 | 0.01373435 | (31)
# bet:aboveEq   :  0.25, reward contract:   0.51, reward model:   0.51, divergence:  0.02%, 29.53:30.83 | 0.01425591 | (33)
# bet:aboveEq   :  0.10, reward contract:   0.20, reward model:   0.20, divergence:  0.04%, 29.78:30.57 | 0.01442976 | (34)
# deposit       :  5.00, shares contract: 493.46, shares model: 495.04, divergence: -0.32%, 29.88:30.47 | 0.01442976 | (35)
# deposit       : 10.00, shares contract: 989.77, shares model: 990.08, divergence: -0.03%, 34.78:35.47 | 0.01460362 | (36)
# bet:below     :  1.00, reward contract:   1.96, reward model:   1.96, divergence: -0.03%, 44.59:45.47 | 0.01460362 | (37)
# deposit       :  5.00, shares contract: 484.23, shares model: 484.38, divergence: -0.03%, 43.63:46.47 | 0.01495132 | (38)
# bet:below     :  1.00, reward contract:   1.92, reward model:   1.92, divergence: -0.03%, 48.32:51.47 | 0.01512517 | (39)
# bet:below     :  0.25, reward contract:   0.47, reward model:   0.47, divergence: -0.03%, 47.40:52.47 | 0.01529903 | (40)
# bet:aboveEq   :  0.10, reward contract:   0.21, reward model:   0.21, divergence:  0.08%, 47.18:52.72 | 0.01547288 | (41)
# deposit       :  2.00, shares contract: 189.10, shares model: 189.56, divergence: -0.24%, 47.28:52.61 | 0.01547288 | (42)
# bet:aboveEq   :  0.50, reward contract:   1.05, reward model:   1.05, divergence:  0.08%, 49.08:54.61 | 0.01582058 | (43)
# bet:aboveEq   :  0.25, reward contract:   0.52, reward model:   0.52, divergence:  0.08%, 49.58:54.06 | 0.01582058 | (44)
# bet:aboveEq   :  0.25, reward contract:   0.52, reward model:   0.52, divergence:  0.08%, 49.83:53.78 | 0.01599444 | (45)
# bet:aboveEq   :  1.00, reward contract:   2.05, reward model:   2.05, divergence:  0.07%, 50.08:53.52 | 0.01616829 | (46)
# bet:aboveEq   :  0.50, reward contract:   1.01, reward model:   1.01, divergence:  0.07%, 51.08:52.47 | 0.01616829 | (47)
# bet:below     :  1.00, reward contract:   1.97, reward model:   1.97, divergence:  0.05%, 51.58:51.96 | 0.01692165 | (48)
# bet:below     :  1.00, reward contract:   1.94, reward model:   1.94, divergence:  0.21%, 50.60:52.96 | 0.01692165 | (49)
# bet:below     :  0.50, reward contract:   0.96, reward model:   0.96, divergence:  0.32%, 49.66:53.96 | 0.01692165 | (50)
# deposit       :  5.00, shares contract: 497.88, shares model: 475.17, divergence:  4.78%, 49.21:54.46 | 0.01692165 | (51)
# bet:below     :  0.25, reward contract:   0.48, reward model:   0.47, divergence:  0.35%, 53.73:59.46 | 0.01709550 | (52)
# bet:aboveEq   :  1.00, reward contract:   2.08, reward model:   2.10, divergence: -0.53%, 53.50:59.71 | 0.01790682 | (53)
# bet:aboveEq   :  1.00, reward contract:   2.05, reward model:   2.06, divergence: -0.50%, 54.50:58.62 | 0.01790682 | (54)
# bet:aboveEq   :  0.10, reward contract:   0.20, reward model:   0.20, divergence: -0.49%, 55.50:57.56 | 0.01790682 | (55)
# bet:below     :  0.10, reward contract:   0.20, reward model:   0.20, divergence:  0.52%, 55.60:57.46 | 0.01790682 | (56)
# bet:aboveEq   :  0.10, reward contract:   0.21, reward model:   0.20, divergence:  3.52%, 55.51:57.56 | 0.01790682 | (57)
# bet:below     :  1.00, reward contract:   1.96, reward model:   1.95, divergence:  0.34%, 55.61:57.45 | 0.01848632 | (58)
# bet:aboveEq   :  0.25, reward contract:   0.51, reward model:   0.52, divergence: -0.31%, 54.65:58.45 | 0.01935559 | (59)
# deposit       :  2.00, shares contract: 194.90, shares model: 194.23, divergence:  0.34%, 54.90:58.19 | 0.01952944 | (60)
# bet:below     :  0.50, reward contract:   0.97, reward model:   0.97, divergence:  0.33%, 56.79:60.19 | 0.02005100 | (61)
# bet:aboveEq   :  0.10, reward contract:   0.20, reward model:   0.21, divergence: -2.07%, 56.32:60.69 | 0.02121001 | (62)
# bet:aboveEq   :  1.00, reward contract:   2.05, reward model:   2.05, divergence: -0.12%, 56.42:60.58 | 0.02121001 | (63)
# bet:below     :  0.10, reward contract:   0.20, reward model:   0.20, divergence:  0.33%, 57.42:59.52 | 0.02155772 | (64)
# deposit       :  1.00, shares contract:  98.36, shares model:  98.03, divergence:  0.33%, 57.33:59.62 | 0.02190542 | (65)
# deposit       : 10.00, shares contract: 983.56, shares model: 980.30, divergence:  0.33%, 58.29:60.62 | 0.02225313 | (66)
# deposit       :  5.00, shares contract: 491.78, shares model: 490.15, divergence:  0.33%, 67.90:70.62 | 0.02300649 | (67)
# bet:aboveEq   :  0.10, reward contract:   0.20, reward model:   0.20, divergence: -0.29%, 72.71:75.62 | 0.02318034 | (68)
# bet:below     :  1.00, reward contract:   1.96, reward model:   1.95, divergence:  0.33%, 72.81:75.52 | 0.02416551 | (69)
# deposit       : 10.00, shares contract: 972.03, shares model: 968.81, divergence:  0.33%, 71.86:76.52 | 0.02433936 | (70)
# bet:aboveEq   :  0.50, reward contract:   1.03, reward model:   1.03, divergence: -0.28%, 81.25:86.52 | 0.02491887 | (71)
# deposit       :  1.00, shares contract:  97.80, shares model:  97.48, divergence:  0.33%, 81.75:85.99 | 0.02509272 | (72)
# bet:aboveEq   :  0.10, reward contract:   0.20, reward model:   0.20, divergence: -0.28%, 82.70:86.99 | 0.02544043 | (73)
# bet:aboveEq   :  0.50, reward contract:   1.02, reward model:   1.02, divergence: -0.28%, 82.80:86.89 | 0.02596198 | (74)
# bet:below     :  0.50, reward contract:   0.98, reward model:   0.98, divergence:  0.32%, 83.30:86.37 | 0.02648354 | (75)
# bet:aboveEq   :  0.10, reward contract:   0.20, reward model:   0.20, divergence: -0.27%, 82.82:86.87 | 0.02683125 | (76)
# deposit       :  2.00, shares contract: 196.11, shares model: 195.47, divergence:  0.32%, 82.92:86.76 | 0.02735280 | (77)
# bet:aboveEq   :  0.50, reward contract:   1.02, reward model:   1.02, divergence: -0.27%, 84.83:88.76 | 0.02770051 | (78)
# deposit       :  2.00, shares contract: 197.26, shares model: 196.62, divergence:  0.32%, 85.33:88.24 | 0.02839592 | (79)
# bet:below     :  0.10, reward contract:   0.20, reward model:   0.20, divergence:  0.32%, 87.27:90.24 | 0.02856977 | (80)
# bet:aboveEq   :  1.00, reward contract:   2.02, reward model:   2.02, divergence: -0.26%, 87.17:90.34 | 0.02909133 | (81)
# bet:aboveEq   :  0.25, reward contract:   0.50, reward model:   0.50, divergence: -0.25%, 88.17:89.32 | 0.02967084 | (82)
# bet:aboveEq   :  0.50, reward contract:   1.00, reward model:   1.00, divergence: -0.25%, 88.42:89.07 | 0.02984469 | (83)
# bet:below     :  0.25, reward contract:   0.50, reward model:   0.50, divergence:  0.32%, 88.92:88.56 | 0.03082986 | (84)
# deposit       :  2.00, shares contract: 199.03, shares model: 199.78, divergence: -0.38%, 88.67:88.81 | 0.03082986 | (85)
# bet:below     :  0.50, reward contract:   1.00, reward model:   1.00, divergence:  0.33%, 90.67:90.81 | 0.03135141 | (86)
# bet:aboveEq   :  0.50, reward contract:   1.00, reward model:   1.00, divergence: -0.25%, 90.17:91.31 | 0.03187297 | (87)
# bet:below     :  1.00, reward contract:   1.99, reward model:   1.99, divergence:  0.32%, 90.67:90.81 | 0.03204682 | (88)
# bet:below     :  0.25, reward contract:   0.49, reward model:   0.49, divergence:  0.32%, 89.69:91.81 | 0.03222068 | (89)
# bet:below     :  0.10, reward contract:   0.20, reward model:   0.20, divergence:  0.32%, 89.44:92.06 | 0.03274223 | (90)
# deposit       :  2.00, shares contract: 197.48, shares model: 196.86, divergence:  0.31%, 89.35:92.16 | 0.03291609 | (91)
# bet:aboveEq   :  1.00, reward contract:   2.01, reward model:   2.02, divergence: -0.25%, 91.28:94.16 | 0.03326379 | (92)
# bet:below     :  0.10, reward contract:   0.20, reward model:   0.20, divergence:  0.32%, 92.28:93.14 | 0.03361150 | (93)
# bet:below     :  0.10, reward contract:   0.20, reward model:   0.20, divergence:  0.32%, 92.19:93.24 | 0.03378535 | (94)

# %%
sum(event.diffs.values())
# Out:
# -6.0

# %%
len(actions)
# Out:
# 95

# %%
positions_raw = endpoint("""
query MyQuery {
  eventByPk(id: 0) {
    positions {
      liquidityProvidedAboveEq
      liquidityProvidedBelow
      rewardAboveEq
      rewardBelow
      shares
      user {
        address
      }
      value
      withdrawn
    }
  }
}
""")

positions = pd.json_normalize(positions_raw['data']['eventByPk']['positions']).set_index('user.address')

# %%
positions
# Out:
#                                       liquidityProvidedAboveEq  \
# user.address
# tz1fvzdyC7s4mMhBrmG38kasaZjE9PHPgFEu                 11.659768
# tz1UZbnprFkQe4qR11m8MFvs19JuEN3r8rG6                 16.508256
# tz1iosWvYEaNdFXC7w6wcn5rFFfFuWaKUMVK                 21.470987
# tz1VRV2jtEVgupzgf4YoXQxK9x6Vksh9tPdM                 18.670077
# tz1RorGpGL42VEkd3zRBK5s8uAk3uuismC2y                 25.975815
#
#                                       liquidityProvidedBelow  rewardAboveEq  \
# user.address
# tz1fvzdyC7s4mMhBrmG38kasaZjE9PHPgFEu               11.918189       7.128656
# tz1UZbnprFkQe4qR11m8MFvs19JuEN3r8rG6               15.720001       6.264887
# tz1iosWvYEaNdFXC7w6wcn5rFFfFuWaKUMVK               21.905145       6.991745
# tz1VRV2jtEVgupzgf4YoXQxK9x6Vksh9tPdM               18.590943       8.059280
# tz1RorGpGL42VEkd3zRBK5s8uAk3uuismC2y               24.405200       5.376724
#
#                                       rewardBelow       shares      value  \
# user.address
# tz1fvzdyC7s4mMhBrmG38kasaZjE9PHPgFEu     4.738721  1178.567848  16.734450
# tz1UZbnprFkQe4qR11m8MFvs19JuEN3r8rG6     9.845787  1594.998435  25.748526
# tz1iosWvYEaNdFXC7w6wcn5rFFfFuWaKUMVK     6.655733  2168.464873  28.685992
# tz1VRV2jtEVgupzgf4YoXQxK9x6Vksh9tPdM     9.883231  1862.376105  28.436689
# tz1RorGpGL42VEkd3zRBK5s8uAk3uuismC2y     5.180865  2495.248004  30.063183
#
#                                       withdrawn
# user.address
# tz1fvzdyC7s4mMhBrmG38kasaZjE9PHPgFEu       True
# tz1UZbnprFkQe4qR11m8MFvs19JuEN3r8rG6       True
# tz1iosWvYEaNdFXC7w6wcn5rFFfFuWaKUMVK       True
# tz1VRV2jtEVgupzgf4YoXQxK9x6Vksh9tPdM       True
# tz1RorGpGL42VEkd3zRBK5s8uAk3uuismC2y       True

# %%
positions.shares - pd.Series(event.shares) / 10**6
# Out:
# tz1RorGpGL42VEkd3zRBK5s8uAk3uuismC2y    30.445696
# tz1UZbnprFkQe4qR11m8MFvs19JuEN3r8rG6    28.039040
# tz1VRV2jtEVgupzgf4YoXQxK9x6Vksh9tPdM     8.640419
# tz1fvzdyC7s4mMhBrmG38kasaZjE9PHPgFEu    36.919466
# tz1iosWvYEaNdFXC7w6wcn5rFFfFuWaKUMVK    27.884329
# dtype: float64

# %%
event.diffs

# %%
event.provide_liquidity('a', 10_000_000, 1, 1)
# Out:
# <Event>
# {
#     "pool_a": 99791222.0,
#     "pool_b": 103304722.0,
#     "total_shares": 10150283908,
#     "fee": 0.025,
#     "winning_pool": "below",
#     "diffs": {
#         "tz1UZbnprFkQe4qR11m8MFvs19JuEN3r8rG6": 999839.0,
#         "tz1iosWvYEaNdFXC7w6wcn5rFFfFuWaKUMVK": -293012.0,
#         "tz1VRV2jtEVgupzgf4YoXQxK9x6Vksh9tPdM": 1481168.0,
#         "tz1fvzdyC7s4mMhBrmG38kasaZjE9PHPgFEu": -799723.0,
#         "tz1RorGpGL42VEkd3zRBK5s8uAk3uuismC2y": -1388278.0
#     },
#     "shares": {
#         "tz1iosWvYEaNdFXC7w6wcn5rFFfFuWaKUMVK": 2140580544,
#         "tz1UZbnprFkQe4qR11m8MFvs19JuEN3r8rG6": 1566959395,
#         "tz1RorGpGL42VEkd3zRBK5s8uAk3uuismC2y": 2464802308,
#         "tz1VRV2jtEVgupzgf4YoXQxK9x6Vksh9tPdM": 1853735686,
#         "tz1fvzdyC7s4mMhBrmG38kasaZjE9PHPgFEu": 1141648382,
#         "a": 982557593
#     }
# }
